# %%
import pandas as pd

# %%
df = pd.read_excel("Data_oct_4.xlsx")

# %%
df.to_csv("Data_oct_4.csv",index = False)

# %%
df
# Out:
#      S.No         Request ID          Citizen Name  rice card no  cluster   \
# 0       1  SCGC2010016583419      Vanamadi Govindu           NaN       NaN
# 1       2  SCGC2010016597680        MOKA CHANDAMMA           NaN       NaN
# 2       3  SCGC2010016601350            Moka Vamsi           NaN       NaN
# 3       4  SCGC2010016603001     Vanamaadi Deepika           NaN       NaN
# 4       5  SCGC2010016621987     Sunnapudi Govindu           NaN       NaN
# ..    ...                ...                   ...           ...       ...
# 115   116  SCGC2102010990146         Moka Sattemma           NaN       NaN
# 116   117  SCGC2102010991193           Nagasuseela           NaN       NaN
# 117   118  SCGC2102011332786  Moka Venkateswararao           NaN       NaN
# 118   119  SCGC2103011448059       Moka Edukondalu           NaN       NaN
# 119   120  SCGC2103011701937     SUNNAPUDI LAKSHMI           NaN       NaN
#
#      Phone Number Ration Card Number
# ...
